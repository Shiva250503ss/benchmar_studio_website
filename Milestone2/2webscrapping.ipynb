# %%
from bs4 import BeautifulSoup
import csv

html_content = '''
<table class="table svelte-82jkx" style="height: 100%; --bw-svt-p-top: 0px; --bw-svt-p-bottom: 930px; --bw-svt-head-height: 37px; --bw-svt-foot-height: 0px; --bw-svt-avg-row-height: 38.75px;"><thead class="thead svelte-82jkx"><tr slot="thead" class="svelte-1oa6fve"><th aria-sort="none" class="svelte-1oa6fve" style="width: var(--cell-width-0);"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">model</span> <div class="sort-button undefined svelte-1oa6fve"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1oa6fve"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1oa6fve" style="width: var(--cell-width-1);"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">Average WER ⬇️</span> <div class="sort-button undefined svelte-1oa6fve"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1oa6fve"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1oa6fve" style="width: var(--cell-width-2);"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">RTFx</span> <div class="sort-button undefined svelte-1oa6fve"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1oa6fve"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1oa6fve" style="width: var(--cell-width-3);"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">AMI</span> <div class="sort-button undefined svelte-1oa6fve"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1oa6fve"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1oa6fve" style="width: var(--cell-width-4);"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">Earnings22</span> <div class="sort-button undefined svelte-1oa6fve"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1oa6fve"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1oa6fve" style="width: var(--cell-width-5);"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">Gigaspeech</span> <div class="sort-button undefined svelte-1oa6fve"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1oa6fve"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1oa6fve" style="width: var(--cell-width-6);"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">LS Clean</span> <div class="sort-button undefined svelte-1oa6fve"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1oa6fve"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1oa6fve" style="width: var(--cell-width-7);"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">LS Other</span> <div class="sort-button undefined svelte-1oa6fve"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1oa6fve"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1oa6fve" style="width: var(--cell-width-8);"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">SPGISpeech</span> <div class="sort-button undefined svelte-1oa6fve"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1oa6fve"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1oa6fve" style="width: var(--cell-width-9);"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">Tedlium</span> <div class="sort-button undefined svelte-1oa6fve"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1oa6fve"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1oa6fve" style="width: var(--cell-width-10);"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">Voxpopuli</span> <div class="sort-button undefined svelte-1oa6fve"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1oa6fve"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th></tr><iframe style="display: block; position: absolute; top: 0; left: 0; width: 100%; height: 100%; overflow: hidden; border: 0; opacity: 0; pointer-events: none; z-index: -1;" aria-hidden="true" tabindex="-1" src="data:text/html,<script>onresize=function(){parent.postMessage(0,'*')}</script>"></iframe></thead> <tbody class="tbody svelte-82jkx"><tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/nvidia/canary-1b" target="_blank" rel="noopener noreferrer">nvidia/canary-1b</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.5</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">235.34</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">13.9</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.19</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.12</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">1.48</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.93</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.06</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.56</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.79</span></div> </td></tr><tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/nvidia/parakeet-tdt-1.1b" target="_blank" rel="noopener noreferrer">nvidia/parakeet-tdt-1.1b</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.01</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2390.61</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.87</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">14.49</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">9.52</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">1.4</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.6</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.16</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.59</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.49</span></div> </td></tr><tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/nvidia/parakeet-rnnt-1.1b" target="_blank" rel="noopener noreferrer">nvidia/parakeet-rnnt-1.1b</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.12</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2053.15</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">17.01</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">13.94</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">9.89</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">1.45</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.5</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.93</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.83</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.44</span></div> </td></tr><tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/nvidia/parakeet-ctc-1.1b" target="_blank" rel="noopener noreferrer">nvidia/parakeet-ctc-1.1b</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.4</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2728.52</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.67</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">13.75</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.28</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">1.83</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.51</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.02</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.57</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.56</span></div> </td></tr><tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/openai/whisper-large-v3" target="_blank" rel="noopener noreferrer">openai/whisper-large-v3</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.44</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">145.51</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.95</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.29</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.02</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.01</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.91</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.94</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.86</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">9.54</span></div> </td></tr><tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/nvidia/parakeet-tdt_ctc-110m" target="_blank" rel="noopener noreferrer">nvidia/parakeet-tdt_ctc-110m</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.49</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5345.14</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.89</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.37</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.52</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.4</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.22</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.54</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.07</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.9</span></div> </td></tr><tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/nvidia/parakeet-rnnt-0.6b" target="_blank" rel="noopener noreferrer">nvidia/parakeet-rnnt-0.6b</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.5</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2815.72</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">17.4</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">14.66</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.01</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">1.62</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.02</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.32</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.85</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.08</span></div> </td></tr><tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/distil-whisper/distil-large-v3" target="_blank" rel="noopener noreferrer">distil-whisper/distil-large-v3</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.52</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">214.42</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.16</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.79</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.08</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.54</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.19</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.27</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.86</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.25</span></div> </td></tr><tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/nvidia/parakeet-ctc-0.6b" target="_blank" rel="noopener noreferrer">nvidia/parakeet-ctc-0.6b</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.69</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4281.53</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16.46</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">14.26</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.39</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">1.88</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.8</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.89</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.77</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.07</span></div> </td></tr><tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/openai/whisper-large-v2" target="_blank" rel="noopener noreferrer">openai/whisper-large-v2</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.83</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">144.45</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16.74</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.05</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.67</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.83</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.14</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.87</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.9</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.48</span></div> </td></tr><tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/distil-whisper/distil-large-v2" target="_blank" rel="noopener noreferrer">distil-whisper/distil-large-v2</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.92</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">202.95</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">14.67</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.19</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.32</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.94</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.84</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.3</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.87</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.24</span></div> </td></tr><tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/openai/whisper-large" target="_blank" rel="noopener noreferrer">openai/whisper-large</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.94</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">143.76</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16.73</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.91</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.76</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.73</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.54</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.2</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.91</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.76</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/distil-whisper/distil-large-v2" target="_blank" rel="noopener noreferrer">distil-whisper/distil-large-v2</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.92</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">202.95</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">14.67</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.19</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.32</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.94</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.84</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.3</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.87</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.24</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/openai/whisper-large" target="_blank" rel="noopener noreferrer">openai/whisper-large</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.94</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">143.76</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16.73</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.91</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.76</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.73</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.54</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.2</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.91</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.76</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/openai/whisper-medium.en" target="_blank" rel="noopener noreferrer">openai/whisper-medium.en</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.09</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">182.13</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16.68</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.63</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.03</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.02</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.85</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.33</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.12</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.06</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/nvidia/stt_en_conformer_ctc_large" target="_blank" rel="noopener noreferrer">nvidia/stt_en_conformer_ctc_large</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.32</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4295.01</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.95</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.99</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.6</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.05</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.15</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.57</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.41</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.83</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/distil-whisper/distil-small.en" target="_blank" rel="noopener noreferrer">distil-whisper/distil-small.en</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.57</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">331.89</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16.16</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">13.15</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.87</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.48</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.73</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.82</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.54</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.79</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve focus"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/openai/whisper-small.en" target="_blank" rel="noopener noreferrer">openai/whisper-small.en</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.59</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">268.91</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">17.93</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.97</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.35</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.05</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.25</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.6</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.07</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.5</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/distil-whisper/distil-medium.en" target="_blank" rel="noopener noreferrer">distil-whisper/distil-medium.en</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.77</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">279.73</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16.12</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.99</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.3</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.69</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.35</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.83</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.84</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">9</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/nvidia/stt_en_fastconformer_ctc_large" target="_blank" rel="noopener noreferrer">nvidia/stt_en_fastconformer_ctc_large</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.96</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6399.25</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.61</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.81</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.17</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">1.93</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.04</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.06</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.76</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.34</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/nvidia/stt_en_fastconformer_transducer_large" target="_blank" rel="noopener noreferrer">nvidia/stt_en_fastconformer_transducer_large</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">9.06</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4097.43</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.09</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.41</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.31</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">1.8</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.97</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.97</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.46</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.45</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/stt_en_conformer_transducer_small" target="_blank" rel="noopener noreferrer">stt_en_conformer_transducer_small</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.26</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3714.36</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">20.28</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.13</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">13.7</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">2.77</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.47</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.63</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.21</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.87</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/openai/whisper-base.en" target="_blank" rel="noopener noreferrer">openai/whisper-base.en</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.32</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">320.67</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">21.13</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.09</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.83</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.25</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.35</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.26</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">4.87</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">9.76</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/nvidia/stt_en_conformer_ctc_small" target="_blank" rel="noopener noreferrer">nvidia/stt_en_conformer_ctc_small</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.16</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5686.9</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">20.43</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.84</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">14.46</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.59</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.92</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.8</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.16</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">9.07</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/openai/whisper-tiny.en" target="_blank" rel="noopener noreferrer">openai/whisper-tiny.en</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.81</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">348.12</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">24.24</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.12</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">14.08</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.66</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.45</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.93</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">5.97</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/speechbrain/asr-wav2vec2-librispeech" target="_blank" rel="noopener noreferrer">speechbrain/asr-wav2vec2-librispeech</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">14.35</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">451.18</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">32.05</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">28.52</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16.92</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">1.77</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">3.83</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.39</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.58</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">13.72</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/facebook/wav2vec2-large-960h-lv60-self" target="_blank" rel="noopener noreferrer">facebook/wav2vec2-large-960h-lv60-self</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">21.27</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">509.32</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">36.77</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">31.68</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">23.94</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.13</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.42</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">17.94</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">14.88</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">21.42</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve focus"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/facebook/mms-1b-all" target="_blank" rel="noopener noreferrer">facebook/mms-1b-all</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.54</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">230.79</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">42.02</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">31.17</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">26.44</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.63</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.99</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16.95</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">17.48</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">17.63</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/facebook/hubert-xlarge-ls960-ft" target="_blank" rel="noopener noreferrer">facebook/hubert-xlarge-ls960-ft</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.55</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">361.32</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">39.11</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">36.13</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">24.74</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.3</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.22</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.58</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.83</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.47</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/facebook/hubert-large-ls960-ft" target="_blank" rel="noopener noreferrer">facebook/hubert-large-ls960-ft</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.69</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">495.86</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">39.72</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">35.24</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">25.01</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.35</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.75</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.86</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.92</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.7</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/facebook/wav2vec2-large-robust-ft-libri-960h" target="_blank" rel="noopener noreferrer">facebook/wav2vec2-large-robust-ft-libri-960h</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.93</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">503.81</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">37.75</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">36.22</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">25.12</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.84</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">13.76</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.03</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16.46</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">23.27</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/facebook/data2vec-audio-large-960h" target="_blank" rel="noopener noreferrer">facebook/data2vec-audio-large-960h</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">23.21</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">470.15</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">40.51</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">37.82</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">24.8</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.4</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.94</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.49</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.86</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">23.86</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/facebook/wav2vec2-conformer-rope-large-960h-ft" target="_blank" rel="noopener noreferrer">facebook/wav2vec2-conformer-rope-large-960h-ft</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">23.28</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">607.87</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">42.47</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">37.52</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">25</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.34</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.54</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.87</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.92</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.61</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/facebook/wav2vec2-conformer-rel-pos-large-960h-ft" target="_blank" rel="noopener noreferrer">facebook/wav2vec2-conformer-rel-pos-large-960h-ft</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">23.29</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">522.46</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">42.39</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">38.33</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">24.96</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.2</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.44</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.85</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.77</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.39</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/facebook/wav2vec2-large-960h" target="_blank" rel="noopener noreferrer">facebook/wav2vec2-large-960h</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">26.77</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">516.58</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">42.66</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">43.75</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">27.74</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.81</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.46</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.82</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.85</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">30.09</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/facebook/data2vec-audio-base-960h" target="_blank" rel="noopener noreferrer">facebook/data2vec-audio-base-960h</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">28.3</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">648.14</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">47.27</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">49.56</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">29.78</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.13</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.48</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">25.46</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.49</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">27.25</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/facebook/wav2vec2-base-960h" target="_blank" rel="noopener noreferrer">facebook/wav2vec2-base-960h</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">29.4</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">686</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">45.56</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">48.47</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">30.85</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.53</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16.72</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">27.56</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">21.05</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">32.48</span></div> </td></tr>
<tr slot="tbody" class="svelte-1oa6fve"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/facebook/mms-1b-fl102" target="_blank" rel="noopener noreferrer">facebook/mms-1b-fl102</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">39.8</span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">234.42</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">86.78</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">51.87</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">42.42</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.07</span></div> </td><td tabindex="0" style="width: var(--cell-width-7);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">28.7</span></div> </td><td tabindex="0" style="width: var(--cell-width-8);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">26.21</span></div> </td><td tabindex="0" style="width: var(--cell-width-9);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">32.35</span></div> </td><td tabindex="0" style="width: var(--cell-width-10);" class="svelte-1oa6fve"><div class="cell-wrap svelte-1oa6fve"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">27.97</span></div> </td></tr>
</tbody> <tfoot class="tfoot svelte-82jkx" style="position: relative;"><iframe style="display: block; position: absolute; top: 0; left: 0; width: 100%; height: 100%; overflow: hidden; border: 0; opacity: 0; pointer-events: none; z-index: -1;" aria-hidden="true" tabindex="-1" src="data:text/html,<script>onresize=function(){parent.postMessage(0,'*')}</script>"></iframe></tfoot></table>
'''

soup = BeautifulSoup(html_content, 'lxml')

table = soup.find('table')
headers = []
for th in table.find('thead').find_all('th'):
    header = th.get_text(strip=True)
    headers.append(header)
rows = []
tbody = table.find('tbody')

for element in tbody.children:
    if element.name == 'tr':
        cells = []
        for td in element.find_all('td'):
            cell_text = td.get_text(strip=True)
            cells.append(cell_text)
        rows.append(cells)
    elif element.name == 'td':
        cells = []
        tds = [element] + list(element.find_next_siblings(lambda x: x.name == 'td'))
        for td in tds:
            cell_text = td.get_text(strip=True)
            cells.append(cell_text)
        rows.append(cells)
        break 

with open('output2.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(headers)
    writer.writerows(rows)

print("Data has been successfully written to 'output2.csv'.")
# Out:
# Data has been successfully written to 'output2.csv'.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data.columns = ['model', 'Average WER', 'RTFx', 'AMI', 'Earnings22', 'Gigaspeech', 'LS Clean', 'LS Other', 'SPGISpeech', 'Tedlium', 'Voxpopuli']

sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sns.barplot(x='model', y='Average WER', data=data)
plt.title('Model Performance: Average WER')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.lineplot(x='model', y='RTFx', marker='o', data=data)
plt.title('Model Speed: RTFx')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.scatterplot(x='model', y='AMI', data=data, s=100)
plt.title('Model AMI Scores')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(x='model', y='Earnings22', data=data)
plt.title('Model Earnings 2022')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.histplot(data=data, x='Gigaspeech', bins=10, kde=True)
plt.title('Distribution of Gigaspeech Scores')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.lineplot(x='model', y='LS Clean', marker='o', data=data)
plt.title('LS Clean Performance Across Models')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.scatterplot(x='model', y='LS Other', data=data, s=100)
plt.title('LS Other Performance Across Models')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(x='model', y='SPGISpeech', data=data)
plt.title('SPGISpeech Performance Variability')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(x='model', y='Tedlium', data=data)
plt.title('Tedlium Performance Across Models')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.histplot(data=data, x='Voxpopuli', bins=10, kde=True)
plt.title('Distribution of Voxpopuli Scores')
plt.tight_layout()
plt.show()
