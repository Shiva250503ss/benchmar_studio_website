# %%
from bs4 import BeautifulSoup
import csv

html_content = '''
<table class="table svelte-1txh5yn" style="height: 100%; --bw-svt-p-top: 0px; --bw-svt-p-bottom: 2267.3939774253154px; --bw-svt-head-height: 37px; --bw-svt-foot-height: 0px; --bw-svt-avg-row-height: 48.24242505160245px;"><thead class="thead svelte-1txh5yn"><tr slot="thead" class="svelte-1bvc1p0"><th aria-sort="none" class="svelte-1bvc1p0" style="width: var(--cell-width-0);"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">T</span> <div class="sort-button undefined svelte-1bvc1p0"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1bvc1p0"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1bvc1p0" style="width: var(--cell-width-1);"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">Model</span> <div class="sort-button undefined svelte-1bvc1p0"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1bvc1p0"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1bvc1p0" style="width: var(--cell-width-2);"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">Win Rate</span> <div class="sort-button undefined svelte-1bvc1p0"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1bvc1p0"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1bvc1p0" style="width: var(--cell-width-3);"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">humaneval-python</span> <div class="sort-button undefined svelte-1bvc1p0"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1bvc1p0"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1bvc1p0" style="width: var(--cell-width-4);"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">java</span> <div class="sort-button undefined svelte-1bvc1p0"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1bvc1p0"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1bvc1p0" style="width: var(--cell-width-5);"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">javascript</span> <div class="sort-button undefined svelte-1bvc1p0"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1bvc1p0"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th><th aria-sort="none" class="svelte-1bvc1p0" style="width: var(--cell-width-6);"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">cpp</span> <div class="sort-button undefined svelte-1bvc1p0"><svg width="1em" height="1em" viewBox="0 0 9 7" fill="none" xmlns="http://www.w3.org/2000/svg" class="svelte-1bvc1p0"><path d="M4.49999 0L8.3971 6.75H0.602875L4.49999 0Z"></path></svg></div></div> </th></tr><iframe style="display: block; position: absolute; top: 0; left: 0; width: 100%; height: 100%; overflow: hidden; border: 0; opacity: 0; pointer-events: none; z-index: -1;" aria-hidden="true" tabindex="-1" src="data:text/html,<script>onresize=function(){parent.postMessage(0,'*')}</script>"></iframe></thead> <tbody class="tbody svelte-1txh5yn"><tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶 EXT</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/m-a-p/OpenCodeInterpreter-DS-33B" target="_blank" rel="noopener noreferrer">OpenCodeInterpreter-DS-33B</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">55.83</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">75.23</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">54.8</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">69.06</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">64.47</span></div> </td></tr><tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶 EXT</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/NTQAI/Nxcode-CQ-7B-orpo" target="_blank" rel="noopener noreferrer">Nxcode-CQ-7B-orpo</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">55.42</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">87.23</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">60.91</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">71.69</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">68.04</span></div> </td></tr><tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/Qwen/CodeQwen1.5-7B-Chat" target="_blank" rel="noopener noreferrer">CodeQwen1.5-7B-Chat</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">55.08</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">87.2</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">61.04</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">70.31</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">67.85</span></div> </td></tr><tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶 EXT</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/codefuse-ai/CodeFuse-DeepSeek-33B" target="_blank" rel="noopener noreferrer">CodeFuse-DeepSeek-33b</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">54.33</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">76.83</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">60.76</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">66.46</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">65.22</span></div> </td></tr><tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶 EXT</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/deepseek-ai/deepseek-coder-33b-instruct" target="_blank" rel="noopener noreferrer">DeepSeek-Coder-33b-instruct</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">52</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">80.02</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">52.03</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">65.13</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">62.36</span></div> </td></tr><tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶 EXT</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/Artigenz/Artigenz-Coder-DS-6.7B" target="_blank" rel="noopener noreferrer">Artigenz-Coder-DS-6.7B</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">51.5</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">70.89</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">56.84</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">66.16</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">59.75</span></div> </td></tr><tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶 EXT</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/deepseek-ai/deepseek-coder-6.7b-instruct" target="_blank" rel="noopener noreferrer">DeepSeek-Coder-7b-instruct</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">50.33</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">80.22</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">53.34</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">65.8</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">59.66</span></div> </td></tr><tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶 EXT</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/m-a-p/OpenCodeInterpreter-DS-6.7B" target="_blank" rel="noopener noreferrer">OpenCodeInterpreter-DS-6.7B</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">49.67</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">73.2</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">51.41</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">63.85</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">60.01</span></div> </td></tr><tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/phind/Phind-CodeLlama-34B-v2" target="_blank" rel="noopener noreferrer">Phind-CodeLlama-34B-v2</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">49.12</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">71.95</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">54.06</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">65.34</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">59.59</span></div> </td></tr><tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/phind/Phind-CodeLlama-34B-v1" target="_blank" rel="noopener noreferrer">Phind-CodeLlama-34B-v1</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">47.92</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">65.85</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">49.47</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">64.45</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">57.81</span></div> </td></tr><tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/phind/Phind-CodeLlama-34B-Python-v1" target="_blank" rel="noopener noreferrer">Phind-CodeLlama-34B-Python-v1</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">46.35</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">70.22</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">48.72</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">66.24</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">55.34</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🟢</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/Qwen/CodeQwen1.5-7B" target="_blank" rel="noopener noreferrer">CodeQwen1.5-7B</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">45.08</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">50.79</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">42.15</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">50.07</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">48.35</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/codellama/CodeLlama-70b-Instruct-hf" target="_blank" rel="noopener noreferrer">CodeLlama-70b-Instruct</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">43.58</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">75.6</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">47.2</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">57.76</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">48.45</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co
</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">17.5</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">27.28</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">24.71</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">29.94</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">29.33</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/smallcloudai/Refact-1_6B-fim" target="_blank" rel="noopener noreferrer">Refact-1.6B</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">17.08</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">31.1</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.78</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.36</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">21.12</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🟢</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0 focus"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/stabilityai/stable-code-3b" target="_blank" rel="noopener noreferrer">Stable-code-3b</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16.17</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">30.72</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">28.75</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">31.64</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">29.42</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🟢 EXT</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/deepseek-ai/deepseek-coder-1.3b-base" target="_blank" rel="noopener noreferrer">DeepSeek-Coder-1b-base</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">16</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">32.13</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">27.16</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">28.46</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">27.96</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🟢</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/bigcode/starcoderbase-3b" target="_blank" rel="noopener noreferrer">StarCoderBase-3B</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">13.73</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">21.5</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.25</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">21.32</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.43</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🔶</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/WizardLM/WizardCoder-1B-V1.0" target="_blank" rel="noopener noreferrer">WizardCoder-1B-V1.0</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">12.27</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">23.17</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.68</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.13</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.94</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🟢</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/replit/replit-code-v1-3b" target="_blank" rel="noopener noreferrer">Replit-2.7B</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.31</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">20.12</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">21.39</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">20.18</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">20.37</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🟢</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/Salesforce/codegen25-7b-mono" target="_blank" rel="noopener noreferrer">CodeGen25-7B-mono</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">9.92</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">33.08</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.75</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">23.22</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.62</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🟢</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/bigcode/starcoderbase-1b" target="_blank" rel="noopener noreferrer">StarCoderBase-1.1B</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">9.88</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.17</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">14.2</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">13.38</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">11.68</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🟢</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/Salesforce/codegen-16B-multi" target="_blank" rel="noopener noreferrer">CodeGen-16B-Multi</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">8.77</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.26</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">22.2</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.15</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">21</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🟢</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/stabilityai/stablecode-completion-alpha-3b" target="_blank" rel="noopener noreferrer">StableCode-3B-alpha</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.73</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">20.2</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.54</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.98</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">20.77</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🟢</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/Deci/DeciCoder-1b" target="_blank" rel="noopener noreferrer">DeciCoder-1B</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">7.5</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.32</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.3</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">17.85</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.87</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0 row_odd"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🟢</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0 focus"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/microsoft/phi-1" target="_blank" rel="noopener noreferrer">Phi-1</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.92</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">51.22</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">10.76</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">19.25</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">14.29</span></div> </td></tr>
<tr slot="tbody" class="svelte-1bvc1p0"><td tabindex="0" style="width: var(--cell-width-0);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">🟢</span></div> </td><td tabindex="0" style="width: var(--cell-width-1);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua"><span class="md svelte-8tpqd2 prose"><p><a style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;" href="https://huggingface.co/bigcode/santacoder" target="_blank" rel="noopener noreferrer">SantaCoder-1.1B</a></p>
</span></span></div> </td><td tabindex="0" style="width: var(--cell-width-2);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.12</span></div> </td><td tabindex="0" style="width: var(--cell-width-3);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">18.12</span></div> </td><td tabindex="0" style="width: var(--cell-width-4);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15</span></div> </td><td tabindex="0" style="width: var(--cell-width-5);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">15.47</span></div> </td><td tabindex="0" style="width: var(--cell-width-6);" class="svelte-1bvc1p0"><div class="cell-wrap svelte-1bvc1p0"> <span tabindex="-1" role="button" style="" class="svelte-z9gpua">6.2</span></div> </td></tr>
</tbody> <tfoot class="tfoot svelte-1txh5yn" style="position: relative;"><iframe style="display: block; position: absolute; top: 0; left: 0; width: 100%; height: 100%; overflow: hidden; border: 0; opacity: 0; pointer-events: none; z-index: -1;" aria-hidden="true" tabindex="-1" src="data:text/html,<script>onresize=function(){parent.postMessage(0,'*')}</script>"></iframe></tfoot></table>
'''

soup = BeautifulSoup(html_content, 'lxml')
table = soup.find('table')
headers = []
for th in table.find('thead').find_all('th'):
    header = th.get_text(strip=True)
    headers.append(header)
rows = []
tbody = table.find('tbody')

for element in tbody.children:
    if element.name == 'tr':
        cells = []
        for td in element.find_all('td'):
            cell_text = td.get_text(strip=True)
            cells.append(cell_text)
        rows.append(cells)
    elif element.name == 'td':
        cells = []
        tds = [element] + list(element.find_next_siblings(lambda x: x.name == 'td'))
        for td in tds:
            cell_text = td.get_text(strip=True)
            cells.append(cell_text)
        rows.append(cells)
        break  # Assuming this is the last row, exit the loop

with open('output1.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(headers)
    writer.writerows(rows)

print("Data has been successfully written to 'output1.csv'.")
# Out:
# Data has been successfully written to 'output1.csv'.

# %%
import pandas as pd

df = pd.read_csv('output1.csv')
df
# Out:
#         T                          Model  Win Rate  humaneval-python   java  \
# 0   🔶 EXT     OpenCodeInterpreter-DS-33B     55.83             75.23  54.80
# 1   🔶 EXT              Nxcode-CQ-7B-orpo     55.42             87.23  60.91
# 2       🔶            CodeQwen1.5-7B-Chat     55.08             87.20  61.04
# 3   🔶 EXT          CodeFuse-DeepSeek-33b     54.33             76.83  60.76
# 4   🔶 EXT    DeepSeek-Coder-33b-instruct     52.00             80.02  52.03
# 5   🔶 EXT         Artigenz-Coder-DS-6.7B     51.50             70.89  56.84
# 6   🔶 EXT     DeepSeek-Coder-7b-instruct     50.33             80.22  53.34
# 7   🔶 EXT    OpenCodeInterpreter-DS-6.7B     49.67             73.20  51.41
# 8       🔶         Phind-CodeLlama-34B-v2     49.12             71.95  54.06
# 9       🔶         Phind-CodeLlama-34B-v1     47.92             65.85  49.47
# 10      🔶  Phind-CodeLlama-34B-Python-v1     46.35             70.22  48.72
# ...

# %%
df.columns[0]
# Out:
# 'T'

# %%
df = df.drop(df.columns[0], axis=1)

output_file_path = 'output1.csv'
df.to_csv(output_file_path, index=False)

df
# Out:
#                             Model  Win Rate  humaneval-python   java  \
# 0      OpenCodeInterpreter-DS-33B     55.83             75.23  54.80
# 1               Nxcode-CQ-7B-orpo     55.42             87.23  60.91
# 2             CodeQwen1.5-7B-Chat     55.08             87.20  61.04
# 3           CodeFuse-DeepSeek-33b     54.33             76.83  60.76
# 4     DeepSeek-Coder-33b-instruct     52.00             80.02  52.03
# 5          Artigenz-Coder-DS-6.7B     51.50             70.89  56.84
# 6      DeepSeek-Coder-7b-instruct     50.33             80.22  53.34
# 7     OpenCodeInterpreter-DS-6.7B     49.67             73.20  51.41
# 8          Phind-CodeLlama-34B-v2     49.12             71.95  54.06
# 9          Phind-CodeLlama-34B-v1     47.92             65.85  49.47
# 10  Phind-CodeLlama-34B-Python-v1     46.35             70.22  48.72
# 11                 CodeQwen1.5-7B     45.08             50.79  42.15
# 12         CodeLlama-70b-Instruct     43.58             75.60  47.20
# ...

# %%
a = df['Model'].unique().tolist()

# %%
len(a)
# Out:
# 55

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data['Average Accuracy'] = data[["humaneval-python", "java", "javascript", "cpp"]].mean(axis=1)
top_10_accuracy_models = data.sort_values(by='Average Accuracy', ascending=False).head(10)
bottom_5_accuracy_models = data.sort_values(by='Average Accuracy', ascending=True).head(5)
combined_models = pd.concat([top_10_accuracy_models, bottom_5_accuracy_models])
combined_models['Category'] = ['Top 10'] * 10 + ['Bottom 5'] * 5

sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Win Rate', hue='Category', data=combined_models)
plt.title('Comparison of Top 10 and Bottom 5 Models: Win Rate')
plt.xticks(rotation=45, ha="right")
plt.legend(title='Model Category')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.lineplot(x='Model', y='humaneval-python', hue='Category', marker='o', data=combined_models)
plt.title('Model Performance: humaneval-python')
plt.xticks(rotation=45, ha="right")
plt.legend(title='Model Category')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Model', y='java', hue='Category', style='Category', s=100, data=combined_models)
plt.title('Model Performance: Java')
plt.xticks(rotation=45, ha="right")
plt.legend(title='Model Category')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='Category', y='javascript', data=combined_models)
plt.title('Model Variability: JavaScript')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(data=combined_models, x='cpp', hue='Category', element='step', binwidth=1)
plt.title('Distribution of Performance: C++')
plt.tight_layout()
plt.show()
